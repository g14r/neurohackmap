# %%
from pip._internal.utils.misc import get_installed_distributions
installed_packages = get_installed_distributions()

installed_packages

import sys
print(sys.executable)
# Out:
# C:\ProgramData\Anaconda3\python.exe

# %%
#install the required packages
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#load in data
df = pd.read_csv('../neuromap_data1-40.csv')

## DATA CLEARNING
#delete first 12 rows
df.drop(df.index[:12], inplace=True)

# # rename column questions to shorter
df.columns = ['timestamp','birth_year', 'birthplace', 'gender','undergrad_loc', 'undergrad_research',
            'masters_loc', 'masters_inst', 'masters_research','doctoral_loc', 'doctoral_inst', 'doctoral_research',
            'undergrad_inst', 'delete', 'ra_lm_loc', 'ra_lm_inst', 'ra_lm_research',
            'postdoc_loc' ,'postdoc_inst','postdoc_research', 'google_scholar', 'twitter', 'linkedin', 'github',
            'undergrad_ra_lm_exp','name','undergrad_deg','masters_qual', 'phd_qual', 'post_doc_qual', 'faculty_qual',
            'faculty_pos', 'prior_progr_lang','faculty_loc','faculty_inst', 'faculty_research', 'consent',
            'delete','delete', 'delete']

#remove unecessary colums
df= df.drop(['delete'], axis=1)
# Out:
#             timestamp birth_year                              birthplace  \
# 12   8/6/2019 5:52:27   16/10/88                           Verona, Italy
# 13  8/6/2019 19:38:09       1991             Northampton, United Kingdom
# 14  8/6/2019 19:39:18       1986                               Hong Kong
# 15  8/6/2019 22:19:20       1988                     Novosibirsk, Russia
# 16  8/6/2019 19:34:13       1994                          Split, Croatia
# 17  8/6/2019 19:37:29       1988                   Verona, Veneto, Italy
# 18  8/6/2019 19:51:26       1992                        Chicago, IL, USA
# 19  8/6/2019 19:53:20       1979              Wichita, KS, United States
# 20  8/6/2019 19:53:48       2019                 Buenos Aires, Argentina
# 21  8/6/2019 19:54:20       1988                             Perm/Russia
# 22  8/6/2019 19:54:41       1984                           Mumbai, India
# 23  8/6/2019 19:55:58       1990                        Cincinnati, Ohio
# 24  8/6/2019 19:57:59       1982            Lafayette, IN, United States
# 25  8/6/2019 19:58:45       1992                      Rockville, MD, USA
# 26  8/6/2019 20:02:31       1991                          Taipei, Taiwan
# 27  8/6/2019 20:03:46       1990                       Vijayawada, India
# 28  8/6/2019 20:06:07       1986                            Brooklyn, NY
# 29  8/6/2019 20:09:05       1990                      Busan, South Korea
# 30  8/6/2019 20:10:30       1993        Tijuana, Baja California, México
# 31  8/6/2019 20:17:56       1989                     Be'er Sheva, Israel
# 32  8/6/2019 20:33:15       1989                 Leiden, the Netherlands
# 33  8/6/2019 20:59:07       1987                           Missouri, USA
# 34  8/6/2019 21:17:11       1990               Wichita Falls, Texas, USA
# 35  8/6/2019 21:18:13        NaN                                     USA
# 36  8/6/2019 21:20:40       1983                      Hollywood, CA, USA
# 37  8/6/2019 21:22:24       1992  Rio de Janeiro, Rio de Janeiro, Brazil
# 38  8/6/2019 21:41:39       1980                          Nairobi, Kenya
# 39  8/6/2019 22:08:45       1990                        Tel Aviv, Israel
# 40  8/6/2019 22:12:23       1987                        Raleigh, NC, USA
# 41  8/6/2019 22:32:59       1986                Kansas City, Kansas, USA
# 42  8/6/2019 22:41:21       1985                        Oakland, CA, USA
# 43  8/6/2019 22:45:39       1984                    Tehran, Tehran, Iran
# 44  8/6/2019 23:25:06       1990                       New York, NY, USA
# 45  8/6/2019 23:28:30       1985                     Portland, Maine, US
# 46  8/6/2019 23:30:45       1988                 London, Ontario, Canada
# 47  8/6/2019 23:42:43       1977                       Jerusalem, Israel
# 48   8/7/2019 0:27:02       1962                     Glen Ridge, NJ, USA
# 49   8/7/2019 0:50:20       1984                      Princeton, NJ, USA
# 50   8/7/2019 0:56:28       1993                 Trento, Trentino, Italy
# 51   8/7/2019 1:54:46       1990                             Teaneck, NJ
# 52   8/7/2019 2:00:46       1991                      Rochester, NY, USA
# 53   8/7/2019 2:02:25       1983                          Manchester, UK
# 54   8/7/2019 2:10:25       1991                Évreux, Normandy, France
#
#     gender                               undergrad_loc  \
# 12    Male                             Rovereto, Italy
# 13  Female                  Wollongong, NSW, Australia
# 14    Male                                   Hong Kong
# 15  Female                         Novosibirsk, Russia
# 16  Female                         Providence, RI, USA
# 17    Male                   Rovereto, Trentino, Italy
# 18  Female                          Ann Arbor, MI, USA
# 19  Female                 Lawrence, KS, United States
# 20  Female                     Buenos Aires, Argentina
# 21  Female                               Moscow/Russia
# 22  Female                               Mumbai, India
# 23  Female                          Palo Alto, CA, USA
# 24    Male           West Lafayette, IN, United States
# 25  Female                             Auburn, AL, USA
# 26  Female                              Taipei, Taiwan
# 27    Male                              Roorkee, India
# 28  Female                Annandale-on-Hudson, NY, USA
# 29  Female                          Seoul, South Korea
# 30  Female            Tijuana, Baja California, México
# 31    Male                                           -
# 32    Male                     Leiden, the Netherlands
# 33    Male                              Tulsa, OK, USA
# 34    Male                         Lubbock, Texas, USA
# 35  Female                Los Angeles, California, USA
# 36    Male                             Orange, CA, USA
# 37    Male      Rio de Janeiro, Rio de Janeiro, Brazil
# 38    Male                              Ottawa, Canada
# 39  Female                           Jerusalem, Israel
# 40    Male  Raleigh & Chapel Hill, North Carolina, USA
# 41    Male                        New Orleans, LA, USA
# 42  Female                   Saratoga Springs, NY, USA
# 43  Female                        Tehran, Tehran, Iran
# 44  Female                           New York, NY, USA
# 45    Male                    colorado springs, CO, US
# 46  Female                    Toronto, Ontario, Canada
# 47    Male                           Jerusalem, Israel
# 48    Male                         Rochester, NY . USA
# 49  Female                          Claremont, CA, USA
# 50    Male                                  London, UK
# 51  Female                                  Boston, MA
# 52  Female                            Hanover, NH, USA
# 53  Female                                 Bristol, UK
# 54    Male                     Rouen, Normandy, France
#
#                                    undergrad_research  \
# 12                                  healthy, tracking
# 13                  cannabis use, EEG, working memory
# 14                    sexual health, clinical, survey
# 15                    mathematics, topology, geometry
# 16  Theory of mind, suicide, development, adolesce...
# 17       healthy, behavioral tracking with IR markers
# 18  Communication neuroscience, social influence, ...
# 19                                                NaN
# 20            psychology, cognitive-neuroscience, eeg
# 21  brain-computer interface, EEG, Matlab, motor i...
# 22                      Globalization and Gender Bias
# 23  vision, retinotopy, eccentricity bias, face pe...
# 24                              Protein Structure NMR
# 25  hypothalamus's structural and functional conne...
# 26  Behavioural/Computational modeling/Category le...
# 27  Electrical Engineering, Control systems, Robotics
# 28                  PET imaging, serotonin, cognition
# 29          (Didn't do research in undergraduate :) )
# 30          Neuropsychology, Psychometry, Methodology
# 31                                                  -
# 32           EEG, cannabis, error related negativity
# 33                                  computer security
# 34     Psychophysiology, Media, Attention, Motivation
# 35                                                NaN
# 36                          Film, Production, Editing
# 37                stress, mice, pfc, D-serine, memory
# 38                             Personality psychology
# 39         psycholinguistics, eye tracker, behavioral
# 40  Human-Attention-EEG&fMRI / Zebrafish-Anxiety-N...
# 41                                    Attention, EEG
# 42     menstrual cycle effects on attention in humans
# 43                                                NaN
# 44                                   Concept learning
# 45              physics, solid state, auger, electron
# 46          animal models of motivation and addiction
# 47                     Structural Biology, Metabolism
# 48                          Physics, x-ray, neutrinos
# 49                    Cellular/molecular neuroscience
# 50         zebrafish, myelin, spinal cord, two-photon
# 51  healthy, multi-modal imaging (sMRI, fMRI, TMS,...
# 52       amygdala, emotion, psychopathy, eye-tracking
# 53                Cancer, melatonin, “light at night”
# 54    Maths and programming. Algorithms, cryptography
#
#                       masters_loc  \
# 12                Rovereto, Italy
# 13                            NaN
# 14                 Birmingham, UK
# 15                Rovereto, Italy
# 16                            NaN
# 17      Rovereto, Trentino, Italy
# 18                            NaN
# 19  Washington, DC, United States
# 20        Buenos Aires, Argentina
# 21                   Neuroscience
# 22      Charlotte, North Carolina
# 23                  Cambridge, UK
# 24                            NaN
# 25                 Miami, FL, USA
# 26                       York, UK
# 27      Edinburgh, United Kingdom
# 28                            NaN
# 29                            NaN
# 30            Mexico city, México
# 31               Tel Aviv, Israel
# 32        Leiden, the Netherlands
# 33                Boston, MA, USA
# 34            Lubbock, Texas, USA
# 35                            NaN
# 36              Portland, OR, USA
# 37                            NaN
# 38                            NaN
# 39                            NaN
# 40                            NaN
# 41           New Orleans, LA, USA
# 42                            NaN
# 43             London, London, UK
# 44             Rochester, NY, USA
# 45                            NaN
# 46      Edinburgh, United Kingdom
# 47              Jerusalem, Israel
# 48              Cambridge, MA USA
# 49                            NaN
# 50                            NaN
# 51                            NaN
# 52                            NaN
# 53         Vancouver, BC, Canada
# 54        Rouen, Normandy, France
#
#                                          masters_inst  \
# 12                                         Uni trento
# 13                                                NaN
# 14                           University of Birmingham
# 15                               University of Trento
# 16                                                NaN
# 17                               University of Trento
# 18                                                NaN
# 19                 The Catholic University of America
# 20                                Favaloro University
# 21                           University of Strasbourg
# 22                                      UNC Charlotte
# 23                            University of Cambridge
# 24                                                NaN
# 25                   Florida International University
# 26                                 University of York
# 27                            University of Edinburgh
# 28                                                NaN
# 29                                                NaN
# 30  Universidad Nacional Autónoma de México; Insti...
# 31                                Tel Aviv University
# 32                      Psychology, Leiden University
# 33                                  Boston University
# 34                              Texas Tech University
# 35                                                NaN
# 36                                 Pacific University
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                  Tulane University
# 42                                                NaN
# 43                                                UCL
# 44                            University of Rochester
# 45                                                NaN
# 46                            University of Edinburgh
# 47                     Hebrew University of Jerusalem
# 48                                                MIT
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                     University of British Columbia
# 54                                University of Rouen
#
#                                      masters_research  \
# 12                               healthy, eyetracking
# 13                                                NaN
# 14  developmental disabilities, eating, cognitive ...
# 15  rats, multisensory perception, tactile perception
# 16                                                NaN
# 17        healthy, eyetracking on pointlight displays
# 18                                                NaN
# 19                 Mental models in science education
# 20             eeg, language-processing, bilingualism
# 21  schizophrenia, animal model, thalamo-cortical ...
# 22                      EEG, PTSD, memory suppression
# 23               vision, autism, children, behavioral
# 24                                                NaN
# 25                        naturalistic fMRI paradigms
# 26  Behavioural/Visual category grouping/Natural s...
# 27         Cognitive Science, Computational Modelling
# 28                                                NaN
# 29                                                NaN
# 30  Neurobiology, Addiction, fMRI, Connectomics, G...
# 31                         Sense of agency using fMRI
# 32  Methods development, cluster and/or component ...
# 33                       cognitive and neural systems
# 34       ADHD, Attention, Learning, Cognitive Control
# 35                                                NaN
# 36                             Counseling, Psychology
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                     EEG, attention
# 42                                                NaN
# 43                                        memory, MEG
# 44                                 Object recognition
# 45                                                NaN
# 46     Social cognition in neurodegenerative diseases
# 47  Audition, blindness, psychophysics, psychometrics
# 48          3d visualization, image segmentation, MRI
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                           myelin, development, MRI
# 54      Algorithms, efficiency, algebra, cryptography
#
#                                    doctoral_loc  ... masters_qual phd_qual  \
# 12                              Rovereto, Italy  ...          Yes      Yes
# 13               Melbourne, Victoria, Australia  ...           No      Yes
# 14                               Birmingham, UK  ...          Yes      Yes
# 15                              Rovereto, Italy  ...          Yes      Yes
# 16                          Pittsburgh, PA, USA  ...           No      Yes
# 17                    Rovereto, Trentino, Italy  ...          Yes      Yes
# 18                        Philadelphia, PA, USA  ...           No      Yes
# 19                               Washington, DC  ...          Yes      Yes
# 20                           Frankfurt, Germany  ...          Yes      Yes
# 21                                 Paris/France  ...          Yes      Yes
# 22                           San Diego, CA, USA  ...          Yes      Yes
# 23                           Princeton, NJ, USA  ...          Yes      Yes
# 24                   Seattle, WA, United States  ...           No      Yes
# 25                               Miami, FL, USA  ...          Yes      Yes
# 26                                     York, UK  ...          Yes      Yes
# 27                             Hamburg, Germany  ...          Yes      Yes
# 28                               Pittsburgh, PA  ...           No      Yes
# 29                           Seoul, South Korea  ...           No      Yes
# 30                                          NaN  ...          Yes       No
# 31                       London, United Kingdom  ...          Yes      Yes
# 32                      Leiden, the Netherlands  ...          Yes      Yes
# 33                              Boston, MA, USA  ...          Yes      Yes
# 34               Santa Barbara, California, USA  ...          Yes      Yes
# 35                  Hanover, New Hampshire, USA  ...           No      Yes
# 36                              Austin, TX, USA  ...          Yes      Yes
# 37  Rio de Janeiro, Brazil AND Montreal, Canada  ...           No      Yes
# 38                           St. Louis, MO, USA  ...           No      Yes
# 39                            Jerusalem, Israel  ...           No      Yes
# 40                         Bloomington, IN, USA  ...           No      Yes
# 41                            Berkeley, CA, USA  ...          Yes      Yes
# 42                               Boston, MA USA  ...           No      Yes
# 43                           London, London, UK  ...          Yes      Yes
# 44                           Rochester, NY, USA  ...          Yes      Yes
# 45                           Washington, DC, US  ...           No      Yes
# 46                      London, Ontario, Canada  ...          Yes      Yes
# 47                            Berkeley, CA, USA  ...          Yes      Yes
# 48                            Cambridge, MA USA  ...          Yes      Yes
# 49                            Berkeley, CA, USA  ...           No      Yes
# 50          Oxford, Oxfordshire, United Kingdom  ...           No      Yes
# 51                                          NaN  ...           No       No
# 52                              Boston, MA, USA  ...           No      Yes
# 53                            Berkeley, CA, USA  ...          Yes      Yes
# 54                 Paris, île-de-France, France  ...          Yes      Yes
#
#    post_doc_qual faculty_qual faculty_pos prior_progr_lang  \
# 12           Yes          NaN         NaN              NaN
# 13            No           No         NaN              NaN
# 14           Yes           No         NaN              NaN
# 15           Yes           No         NaN              NaN
# 16            No           No         NaN              NaN
# 17           Yes           No         NaN              NaN
# 18            No           No         NaN              NaN
# 19           Yes          Yes         NaN              NaN
# 20            No           No         NaN              NaN
# 21           Yes          Yes         NaN              NaN
# 22           Yes           No         NaN              NaN
# 23            No           No         NaN              NaN
# 24           Yes           No         NaN              NaN
# 25            No           No         NaN              NaN
# 26           Yes           No         NaN              NaN
# 27            No           No         NaN              NaN
# 28           Yes           No         NaN              NaN
# 29           Yes           No         NaN              NaN
# 30            No           No         NaN              NaN
# 31            No           No         NaN              NaN
# 32            No           No         NaN              NaN
# 33            No           No         NaN              NaN
# 34            No           No         NaN              NaN
# 35            No           No         NaN              NaN
# 36            No           No         NaN              NaN
# 37           Yes           No         NaN              NaN
# 38           Yes          Yes         NaN              NaN
# 39            No           No         NaN              NaN
# 40            No           No         NaN              NaN
# 41           Yes           No         NaN              NaN
# 42           Yes           No         NaN              NaN
# 43           Yes           No         NaN              NaN
# 44            No           No         NaN              NaN
# 45           Yes           No         NaN              NaN
# 46           Yes           No         NaN              NaN
# 47           Yes          Yes         NaN              NaN
# 48           Yes          Yes         NaN              NaN
# 49           Yes          Yes         NaN              NaN
# 50            No           No         NaN              NaN
# 51            No           No         NaN              NaN
# 52            No           No         NaN              NaN
# 53           Yes          Yes         NaN              NaN
# 54           Yes           No         NaN              NaN
#
#                   faculty_loc                                faculty_inst  \
# 12                        NaN                                         NaN
# 13                        NaN                                         NaN
# 14                        NaN                                         NaN
# 15                        NaN                                         NaN
# 16                        NaN                                         NaN
# 17                        NaN                                         NaN
# 18                        NaN                                         NaN
# 19  Dallas, TX, United States               University of Texas at Dallas
# 20                        NaN                                         NaN
# 21               Perm, Russia                  Higher School of Economics
# 22                        NaN                                         NaN
# 23                        NaN                                         NaN
# 24                        NaN                                         NaN
# 25                        NaN                                         NaN
# 26                        NaN                                         NaN
# 27                        NaN                                         NaN
# 28                        NaN                                         NaN
# 29                        NaN                                         NaN
# 30                        NaN                                         NaN
# 31                        NaN                                         NaN
# 32                        NaN                                         NaN
# 33                        NaN                                         NaN
# 34                        NaN                                         NaN
# 35                        NaN                                         NaN
# 36                        NaN                                         NaN
# 37                        NaN                                         NaN
# 38            Austin, TX, USA               University of Texas at Austin
# 39                        NaN                                         NaN
# 40                        NaN                                         NaN
# 41                        NaN                                         NaN
# 42                        NaN                                         NaN
# 43                        NaN                                         NaN
# 44                        NaN                                         NaN
# 45                        NaN                                         NaN
# 46                        NaN                                         NaN
# 47           Seattle, WA, USA                    University of Washington
# 48          Worcester, MA USA  University of Massachusetts Medical School
# 49            Austin, TX, USA                                   UT Austin
# 50                        NaN                                         NaN
# 51                        NaN                                         NaN
# 52                        NaN                                         NaN
# 53                 London, UK                       Alan Turing Institute
# 54                        NaN                                         NaN
#
#                                      faculty_research consent
# 12                                                NaN     NaN
# 13                                                NaN     Yes
# 14                                                NaN     Yes
# 15                                                NaN     Yes
# 16                                                NaN     Yes
# 17                                                NaN     Yes
# 18                                                NaN     Yes
# 19                   Aging, Decision making, Learning     Yes
# 20                                                NaN     Yes
# 21  diffusion MRI, MRI relaxometry, TMS, EEG, stro...     Yes
# 22                                                NaN     Yes
# 23                                                NaN     Yes
# 24                                                NaN     Yes
# 25                                                NaN     Yes
# 26                                                NaN     Yes
# 27                                                NaN     Yes
# 28                                                NaN     Yes
# 29                                                NaN     Yes
# 30                                                NaN     Yes
# 31                                                NaN     Yes
# 32                                                NaN     Yes
# 33                                                NaN     Yes
# 34                                                NaN     Yes
# 35                                                NaN     Yes
# 36                                                NaN     Yes
# 37                                                NaN     Yes
# 38                                   Neuroinformatics     Yes
# 39                                                NaN     Yes
# 40                                                NaN     Yes
# 41                                                NaN     Yes
# 42                                                NaN     Yes
# 43                                                NaN     Yes
# 44                                                NaN     Yes
# 45                                                NaN     Yes
# 46                                                NaN     Yes
# 47  Data science, neuroinformatics, machine learni...     Yes
# 48  brain development, neurodevelopmental disorder...     Yes
# 49  epilepsy, ECoG, EEG, speech perception, audito...     Yes
# 50                                                NaN     Yes
# 51                                                NaN     Yes
# 52                                                NaN     Yes
# 53        “Data science”, reproducible, “open source”     Yes
# 54                                                NaN     Yes
#
# [43 rows x 36 columns]

# %%
doc_loc = df.doctoral_loc
doc_loc
# Out:
# 12                                Rovereto, Italy
# 13                 Melbourne, Victoria, Australia
# 14                                 Birmingham, UK
# 15                                Rovereto, Italy
# 16                            Pittsburgh, PA, USA
# 17                      Rovereto, Trentino, Italy
# 18                          Philadelphia, PA, USA
# 19                                 Washington, DC
# 20                             Frankfurt, Germany
# 21                                   Paris/France
# 22                             San Diego, CA, USA
# 23                             Princeton, NJ, USA
# 24                     Seattle, WA, United States
# 25                                 Miami, FL, USA
# 26                                       York, UK
# 27                               Hamburg, Germany
# 28                                 Pittsburgh, PA
# 29                             Seoul, South Korea
# 30                                            NaN
# 31                         London, United Kingdom
# 32                        Leiden, the Netherlands
# 33                                Boston, MA, USA
# 34                 Santa Barbara, California, USA
# 35                    Hanover, New Hampshire, USA
# 36                                Austin, TX, USA
# 37    Rio de Janeiro, Brazil AND Montreal, Canada
# 38                             St. Louis, MO, USA
# 39                              Jerusalem, Israel
# 40                           Bloomington, IN, USA
# 41                              Berkeley, CA, USA
# 42                                 Boston, MA USA
# 43                             London, London, UK
# 44                             Rochester, NY, USA
# 45                             Washington, DC, US
# 46                        London, Ontario, Canada
# 47                              Berkeley, CA, USA
# 48                              Cambridge, MA USA
# 49                              Berkeley, CA, USA
# 50            Oxford, Oxfordshire, United Kingdom
# 51                                            NaN
# 52                                Boston, MA, USA
# 53                              Berkeley, CA, USA
# 54                   Paris, île-de-France, France
# Name: doctoral_loc, dtype: object

# %%
#view the first 10 rows of a specific column
doc_res = df.doctoral_research
doc_res.head(10)
# Out:
# 12                     healthy, fmri, movement decoding
# 13    mild traumatic brain injury, TMS-EEG, neuropsy...
# 14    temporal, parietal areas; lesion analysis, fmr...
# 15    fMRI, vision, ventral stream, object perceptio...
# 16              development, psychosis, fMRI, thalamus
# 17                     healthy, fMRI, movement decoding
# 18    adolescent decision-making, fMRI, reward proce...
# 19               aging and experiential decision making
# 20    MEG, fMRI, predictive-processing, schema proce...
# 21    neuroimaging, brain development, myelin, pytho...
# Name: doctoral_research, dtype: object

# %%
#to check 
a = doc_res.unique()
b = len(doc_res.unique())
        
print (a,b)
# Out:
# ['healthy, fmri, movement decoding'
#  'mild traumatic brain injury, TMS-EEG, neuropsychology'
#  'temporal, parietal areas; lesion analysis, fmri, stroke'
#  'fMRI, vision, ventral stream, object perception, animacy'
#  'development, psychosis, fMRI, thalamus '
#  'healthy, fMRI, movement decoding'
#  'adolescent decision-making, fMRI, reward processing, development, risk-taking'
#  'aging and experiential decision making'
#  'MEG, fMRI, predictive-processing, schema processing, episodic memory'
#  'neuroimaging, brain development, myelin, python, BrainVISA'
#  'Autism, multimodal imaging, thalamus, neuropsychology'
#  'communication, naturalistic, human fMRI,  neural synchrony'
#  'molucular dynamics simulation analysis'
#  'large-scale brain network variability wrt ovarian hormones'
#  'Functional connectivity/Resting state/ Default mode network/Mind wandering/'
#  'Decision Making, fMRI, Behavioural Modelling'
#  'addiction, mood disorders, adolescent development, MRI, diffusion imaging'
#  'medial prefrontal cortex, development, self-protection, social evaluation, social function'
#  nan 'Metacognitive evaluation of inference about absence'
#  'Methods development, cluster and/or component analysis'
#  'multivariate analysis of speech fmri'
#  'Network neuroscience, ADHD, attention, motivation, cognitive control'
#  'Computational Social Neuroscience'
#  'rs-fcMRI, development, executive function'
#  'cognitive training, neuroplasticity, schizophrenia, D-serine, electrophysiology'
#  'Cognitive neuroscience, decision-making'
#  'dyslexia, fmri, perception, memory'
#  'White matter anatomy / Computational Neuroanatomy'
#  'Computational neuroscience, audition, language, natural stimuli'
#  'memory, attention, human fMRI, parietal lobe, adults'
#  'MEG, machine learning, memory' 'Object processing along visual streams'
#  'pediatric, motor, fmri, brain'
#  'Social cognition in frontotemporal dementia'
#  'Vision, Acetyl-choline, perceptual learning, motion perception'
#  'multiple quantum MRI imaging, MRI, vascular disease'
#  'Mice, Electrophysiology, auditory cortex'
#  'Plasticity, white matter, diffusion, qMRI, TMS'
#  'affective neuroscience, childhood trauma, clinical psychology'
#  'Reasoning, “white matter”, development'
#  'Lesion-deficit analyses, methodology'] 42

# %%
text=" ".join(str(dscp) for dscp in doc_res)
#text

# %%
#?WordCloud

text=" ".join(str(dscp) for dscp in doc_res)
print ("{} words in all combined review.".format(len(text)))

stopwords=set(STOPWORDS)
stopwords.update(["in","along","and","making"])
# Out:
# 2117 words in all combined review.

# %%
#Values of 255 are pure white, whereas values of 1 are black. 
#Use the function below to transform mask if the mask has the same format as above. Notice if you have a mask that the background is not 0, but 1 or 2, adjust the function to match your mask.

def transform_format(val):
    if val == 0:
        return 255
    else:
        return val

# %%
head_mask = np.array(Image.open("img/head.png"))
if len(head_mask.shape) ==3:
 head_mask = head_mask[:,:,-1]

# %%
# Transform your mask into a new one that will work with the function:
tf_head_mask = np.ndarray((head_mask.shape[0],head_mask.shape[1]), np.int32)

for i in range(len(head_mask)):
    tf_head_mask[i] = list(map(transform_format, head_mask[i]))
    
tf_head_mask
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]])

# %%
# Create and generate a word cloud image:
wdcd = WordCloud(mask=tf_head_mask, stopwords=stopwords, max_font_size=50, max_words=1000, background_color="white", contour_width=3, contour_color='firebrick')
wdcd.generate(text)

# Display the generated image:
plt.figure(figsize=[40,20])
plt.imshow(wdcd, interpolation='bilinear')
plt.axis("off")



# Save the image in the img folder:
#wordcloud.to_file("img/first_review.png")
# Out:
# (-0.5, 685.5, 755.5, -0.5)

# %%
brain_mask = np.array(Image.open("img/brain.png"))
if len(brain_mask.shape) ==3:
 brain_mask = brain_mask[:,:,-1]

# %%
# Transform your mask into a new one that will work with the function:
tf_brain_mask = np.ndarray((brain_mask.shape[0],brain_mask.shape[1]), np.int32)


for i in range(len(brain_mask)):
    tf_brain_mask[i] = list(map(transform_format, brain_mask[i]))
    
tf_brain_mask
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]])

# %%
# Create and generate a word cloud image:
wdcd = WordCloud(mask=brain_mask, stopwords=stopwords, max_font_size=50, max_words=1000, background_color="white", contour_width=3, contour_color='firebrick')
wdcd.generate(text)

# Display the generated image:
plt.figure(figsize=[40,20])

plt.imshow(wdcd, interpolation='bilinear')
plt.axis("off")


# Save the image in the img folder:
#wordcloud.to_file("img/first_review.png")
# Out:
# (-0.5, 688.5, 588.5, -0.5)

# %%
#to import neccessary module to run interactive features
import ipywidgets as widgets

# %%
#NOT NEEDED AT THE MOMENT
#fig, axs = plt.subplots(2,2)
#ax=axs[1,0]
#ax.imshow(wdcd, interpolation='bilinear')
#ax.set_axis_off()

#axs

# %%
df.doctoral_loc.head()

doc_loc_list = df.doctoral_loc

df_doc_loc = df.dropna(subset=["doctoral_loc"])
#if None in doc_loc_list: doc_loc_list.remove(None)

df_doc_loc.loc[:,"doctoral_loc"]

replace_dict = {
    "Tijuana, Baja California, MÌ©xico": "Tijuana, Baja California, Mexico",
    'Raleigh & Chapel Hill, North Carolina, USA': 'Chapel Hill, North Carolina, USA'
}
df['undergrad_loc'] = df['undergrad_loc'].replace(replace_dict)    

#print(df.shape, df_doc_loc.shape)
# Out:
# 12                                Rovereto, Italy
# 13                 Melbourne, Victoria, Australia
# 14                                 Birmingham, UK
# 15                                Rovereto, Italy
# 16                            Pittsburgh, PA, USA
# 17                      Rovereto, Trentino, Italy
# 18                          Philadelphia, PA, USA
# 19                                 Washington, DC
# 20                             Frankfurt, Germany
# 21                                   Paris/France
# 22                             San Diego, CA, USA
# 23                             Princeton, NJ, USA
# 24                     Seattle, WA, United States
# 25                                 Miami, FL, USA
# 26                                       York, UK
# 27                               Hamburg, Germany
# 28                                 Pittsburgh, PA
# 29                             Seoul, South Korea
# 31                         London, United Kingdom
# 32                        Leiden, the Netherlands
# 33                                Boston, MA, USA
# 34                 Santa Barbara, California, USA
# 35                    Hanover, New Hampshire, USA
# 36                                Austin, TX, USA
# 37    Rio de Janeiro, Brazil AND Montreal, Canada
# 38                             St. Louis, MO, USA
# 39                              Jerusalem, Israel
# 40                           Bloomington, IN, USA
# 41                              Berkeley, CA, USA
# 42                                 Boston, MA USA
# 43                             London, London, UK
# 44                             Rochester, NY, USA
# 45                             Washington, DC, US
# 46                        London, Ontario, Canada
# 47                              Berkeley, CA, USA
# 48                              Cambridge, MA USA
# 49                              Berkeley, CA, USA
# 50            Oxford, Oxfordshire, United Kingdom
# 52                                Boston, MA, USA
# 53                              Berkeley, CA, USA
# 54                   Paris, île-de-France, France
# Name: doctoral_loc, dtype: object

# %%
import geopy
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="neuromap_cloud")

#Loop through rows to get the longitude and latitude of the hometowns
lat=[]
long=[]
for home_location in df_doc_loc.loc[:,"doctoral_loc"]:
    location_1 = geolocator.geocode(home_location, timeout=10)
    print((location_1.latitude, location_1.longitude, home_location))
    
    #lat.append(location_1.latitude)
    #long.append(location_1.longitude)
    
#Saving lat and long in separate columns in the dataframe    
#df['DocTownLatitude'] = lat
#df['DocTownLatitude'] = df['DocTownLatitude'].astype('float')

#df['DocTownLongitude'] = long
#df['DocTownLongitude'] = df['DocTownLongitude'].astype('float')
    
#lat
# Out:
# (45.886548, 11.0452369, 'Rovereto, Italy')
# (-37.8142176, 144.9631608, 'Melbourne, Victoria, Australia')
# (52.4775396, -1.894053, 'Birmingham, UK')
# (45.886548, 11.0452369, 'Rovereto, Italy')
# (40.4416941, -79.9900861, 'Pittsburgh, PA, USA')
# (45.886548, 11.0452369, 'Rovereto, Trentino, Italy')
# (39.9527237, -75.1635262, 'Philadelphia, PA, USA')
# (38.8950092, -77.0365625, 'Washington, DC')
# (50.1106444, 8.6820917, 'Frankfurt, Germany')
# (48.8566101, 2.3514992, 'Paris/France')
# (32.7174209, -117.1627714, 'San Diego, CA, USA')
# (40.3492744, -74.6592958, 'Princeton, NJ, USA')
# (47.6038321, -122.3300624, 'Seattle, WA, United States')
# (25.7742658, -80.1936589, 'Miami, FL, USA')
# (53.9590555, -1.0815361, 'York, UK')
# (53.550341, 10.000654, 'Hamburg, Germany')
# (40.4416941, -79.9900861, 'Pittsburgh, PA')
# (37.5666791, 126.9782914, 'Seoul, South Korea')
# (51.5073219, -0.1276474, 'London, United Kingdom')
# (52.1518157, 4.48110886662043, 'Leiden, the Netherlands')
# (42.3602534, -71.0582912, 'Boston, MA, USA')
# (34.4221319, -119.7026673, 'Santa Barbara, California, USA')
# (43.703622, -72.288666, 'Hanover, New Hampshire, USA')
# (35.5306348, -92.7907215, 'Austin, TX, USA')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-0213ce441feb> in <module>
#       8 for home_location in df_doc_loc.loc[:,"doctoral_loc"]:
#       9     location_1 = geolocator.geocode(home_location, timeout=10)
# ---> 10     print((location_1.latitude, location_1.longitude, home_location))
#      11
#      12     #lat.append(location_1.latitude)
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
df['doc_continent'] =[]

import re
strings = ["Important text,      Comment that could be removed", "Other String"]
[re.sub("(,[ ]*!.*)$", "", x) for x in strings]
# Out:
# ['Important text,      .Comment that could be removed', 'Other String']

# %%
df['doc_continent'] = doc_loc
#df.doc_continent = r 
re.sub("")
# Out:
#             timestamp birth_year                              birthplace  \
# 12   8/6/2019 5:52:27   16/10/88                           Verona, Italy
# 13  8/6/2019 19:38:09       1991             Northampton, United Kingdom
# 14  8/6/2019 19:39:18       1986                               Hong Kong
# 15  8/6/2019 22:19:20       1988                     Novosibirsk, Russia
# 16  8/6/2019 19:34:13       1994                          Split, Croatia
# 17  8/6/2019 19:37:29       1988                   Verona, Veneto, Italy
# 18  8/6/2019 19:51:26       1992                        Chicago, IL, USA
# 19  8/6/2019 19:53:20       1979              Wichita, KS, United States
# 20  8/6/2019 19:53:48       2019                 Buenos Aires, Argentina
# 21  8/6/2019 19:54:20       1988                             Perm/Russia
# 22  8/6/2019 19:54:41       1984                           Mumbai, India
# 23  8/6/2019 19:55:58       1990                        Cincinnati, Ohio
# 24  8/6/2019 19:57:59       1982            Lafayette, IN, United States
# 25  8/6/2019 19:58:45       1992                      Rockville, MD, USA
# 26  8/6/2019 20:02:31       1991                          Taipei, Taiwan
# 27  8/6/2019 20:03:46       1990                       Vijayawada, India
# 28  8/6/2019 20:06:07       1986                            Brooklyn, NY
# 29  8/6/2019 20:09:05       1990                      Busan, South Korea
# 30  8/6/2019 20:10:30       1993        Tijuana, Baja California, México
# 31  8/6/2019 20:17:56       1989                     Be'er Sheva, Israel
# 32  8/6/2019 20:33:15       1989                 Leiden, the Netherlands
# 33  8/6/2019 20:59:07       1987                           Missouri, USA
# 34  8/6/2019 21:17:11       1990               Wichita Falls, Texas, USA
# 35  8/6/2019 21:18:13        NaN                                     USA
# 36  8/6/2019 21:20:40       1983                      Hollywood, CA, USA
# 37  8/6/2019 21:22:24       1992  Rio de Janeiro, Rio de Janeiro, Brazil
# 38  8/6/2019 21:41:39       1980                          Nairobi, Kenya
# 39  8/6/2019 22:08:45       1990                        Tel Aviv, Israel
# 40  8/6/2019 22:12:23       1987                        Raleigh, NC, USA
# 41  8/6/2019 22:32:59       1986                Kansas City, Kansas, USA
# 42  8/6/2019 22:41:21       1985                        Oakland, CA, USA
# 43  8/6/2019 22:45:39       1984                    Tehran, Tehran, Iran
# 44  8/6/2019 23:25:06       1990                       New York, NY, USA
# 45  8/6/2019 23:28:30       1985                     Portland, Maine, US
# 46  8/6/2019 23:30:45       1988                 London, Ontario, Canada
# 47  8/6/2019 23:42:43       1977                       Jerusalem, Israel
# 48   8/7/2019 0:27:02       1962                     Glen Ridge, NJ, USA
# 49   8/7/2019 0:50:20       1984                      Princeton, NJ, USA
# 50   8/7/2019 0:56:28       1993                 Trento, Trentino, Italy
# 51   8/7/2019 1:54:46       1990                             Teaneck, NJ
# 52   8/7/2019 2:00:46       1991                      Rochester, NY, USA
# 53   8/7/2019 2:02:25       1983                          Manchester, UK
# 54   8/7/2019 2:10:25       1991                Évreux, Normandy, France
#
#     gender                               undergrad_loc  \
# 12    Male                             Rovereto, Italy
# 13  Female                  Wollongong, NSW, Australia
# 14    Male                                   Hong Kong
# 15  Female                         Novosibirsk, Russia
# 16  Female                         Providence, RI, USA
# 17    Male                   Rovereto, Trentino, Italy
# 18  Female                          Ann Arbor, MI, USA
# 19  Female                 Lawrence, KS, United States
# 20  Female                     Buenos Aires, Argentina
# 21  Female                               Moscow/Russia
# 22  Female                               Mumbai, India
# 23  Female                          Palo Alto, CA, USA
# 24    Male           West Lafayette, IN, United States
# 25  Female                             Auburn, AL, USA
# 26  Female                              Taipei, Taiwan
# 27    Male                              Roorkee, India
# 28  Female                Annandale-on-Hudson, NY, USA
# 29  Female                          Seoul, South Korea
# 30  Female            Tijuana, Baja California, México
# 31    Male                                           -
# 32    Male                     Leiden, the Netherlands
# 33    Male                              Tulsa, OK, USA
# 34    Male                         Lubbock, Texas, USA
# 35  Female                Los Angeles, California, USA
# 36    Male                             Orange, CA, USA
# 37    Male      Rio de Janeiro, Rio de Janeiro, Brazil
# 38    Male                              Ottawa, Canada
# 39  Female                           Jerusalem, Israel
# 40    Male  Raleigh & Chapel Hill, North Carolina, USA
# 41    Male                        New Orleans, LA, USA
# 42  Female                   Saratoga Springs, NY, USA
# 43  Female                        Tehran, Tehran, Iran
# 44  Female                           New York, NY, USA
# 45    Male                    colorado springs, CO, US
# 46  Female                    Toronto, Ontario, Canada
# 47    Male                           Jerusalem, Israel
# 48    Male                         Rochester, NY . USA
# 49  Female                          Claremont, CA, USA
# 50    Male                                  London, UK
# 51  Female                                  Boston, MA
# 52  Female                            Hanover, NH, USA
# 53  Female                                 Bristol, UK
# 54    Male                     Rouen, Normandy, France
#
#                                    undergrad_research  \
# 12                                  healthy, tracking
# 13                  cannabis use, EEG, working memory
# 14                    sexual health, clinical, survey
# 15                    mathematics, topology, geometry
# 16  Theory of mind, suicide, development, adolesce...
# 17       healthy, behavioral tracking with IR markers
# 18  Communication neuroscience, social influence, ...
# 19                                                NaN
# 20            psychology, cognitive-neuroscience, eeg
# 21  brain-computer interface, EEG, Matlab, motor i...
# 22                      Globalization and Gender Bias
# 23  vision, retinotopy, eccentricity bias, face pe...
# 24                              Protein Structure NMR
# 25  hypothalamus's structural and functional conne...
# 26  Behavioural/Computational modeling/Category le...
# 27  Electrical Engineering, Control systems, Robotics
# 28                  PET imaging, serotonin, cognition
# 29          (Didn't do research in undergraduate :) )
# 30          Neuropsychology, Psychometry, Methodology
# 31                                                  -
# 32           EEG, cannabis, error related negativity
# 33                                  computer security
# 34     Psychophysiology, Media, Attention, Motivation
# 35                                                NaN
# 36                          Film, Production, Editing
# 37                stress, mice, pfc, D-serine, memory
# 38                             Personality psychology
# 39         psycholinguistics, eye tracker, behavioral
# 40  Human-Attention-EEG&fMRI / Zebrafish-Anxiety-N...
# 41                                    Attention, EEG
# 42     menstrual cycle effects on attention in humans
# 43                                                NaN
# 44                                   Concept learning
# 45              physics, solid state, auger, electron
# 46          animal models of motivation and addiction
# 47                     Structural Biology, Metabolism
# 48                          Physics, x-ray, neutrinos
# 49                    Cellular/molecular neuroscience
# 50         zebrafish, myelin, spinal cord, two-photon
# 51  healthy, multi-modal imaging (sMRI, fMRI, TMS,...
# 52       amygdala, emotion, psychopathy, eye-tracking
# 53                Cancer, melatonin, “light at night”
# 54    Maths and programming. Algorithms, cryptography
#
#                       masters_loc  \
# 12                Rovereto, Italy
# 13                            NaN
# 14                 Birmingham, UK
# 15                Rovereto, Italy
# 16                            NaN
# 17      Rovereto, Trentino, Italy
# 18                            NaN
# 19  Washington, DC, United States
# 20        Buenos Aires, Argentina
# 21                   Neuroscience
# 22      Charlotte, North Carolina
# 23                  Cambridge, UK
# 24                            NaN
# 25                 Miami, FL, USA
# 26                       York, UK
# 27      Edinburgh, United Kingdom
# 28                            NaN
# 29                            NaN
# 30            Mexico city, México
# 31               Tel Aviv, Israel
# 32        Leiden, the Netherlands
# 33                Boston, MA, USA
# 34            Lubbock, Texas, USA
# 35                            NaN
# 36              Portland, OR, USA
# 37                            NaN
# 38                            NaN
# 39                            NaN
# 40                            NaN
# 41           New Orleans, LA, USA
# 42                            NaN
# 43             London, London, UK
# 44             Rochester, NY, USA
# 45                            NaN
# 46      Edinburgh, United Kingdom
# 47              Jerusalem, Israel
# 48              Cambridge, MA USA
# 49                            NaN
# 50                            NaN
# 51                            NaN
# 52                            NaN
# 53         Vancouver, BC, Canada
# 54        Rouen, Normandy, France
#
#                                          masters_inst  \
# 12                                         Uni trento
# 13                                                NaN
# 14                           University of Birmingham
# 15                               University of Trento
# 16                                                NaN
# 17                               University of Trento
# 18                                                NaN
# 19                 The Catholic University of America
# 20                                Favaloro University
# 21                           University of Strasbourg
# 22                                      UNC Charlotte
# 23                            University of Cambridge
# 24                                                NaN
# 25                   Florida International University
# 26                                 University of York
# 27                            University of Edinburgh
# 28                                                NaN
# 29                                                NaN
# 30  Universidad Nacional Autónoma de México; Insti...
# 31                                Tel Aviv University
# 32                      Psychology, Leiden University
# 33                                  Boston University
# 34                              Texas Tech University
# 35                                                NaN
# 36                                 Pacific University
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                  Tulane University
# 42                                                NaN
# 43                                                UCL
# 44                            University of Rochester
# 45                                                NaN
# 46                            University of Edinburgh
# 47                     Hebrew University of Jerusalem
# 48                                                MIT
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                     University of British Columbia
# 54                                University of Rouen
#
#                                      masters_research  \
# 12                               healthy, eyetracking
# 13                                                NaN
# 14  developmental disabilities, eating, cognitive ...
# 15  rats, multisensory perception, tactile perception
# 16                                                NaN
# 17        healthy, eyetracking on pointlight displays
# 18                                                NaN
# 19                 Mental models in science education
# 20             eeg, language-processing, bilingualism
# 21  schizophrenia, animal model, thalamo-cortical ...
# 22                      EEG, PTSD, memory suppression
# 23               vision, autism, children, behavioral
# 24                                                NaN
# 25                        naturalistic fMRI paradigms
# 26  Behavioural/Visual category grouping/Natural s...
# 27         Cognitive Science, Computational Modelling
# 28                                                NaN
# 29                                                NaN
# 30  Neurobiology, Addiction, fMRI, Connectomics, G...
# 31                         Sense of agency using fMRI
# 32  Methods development, cluster and/or component ...
# 33                       cognitive and neural systems
# 34       ADHD, Attention, Learning, Cognitive Control
# 35                                                NaN
# 36                             Counseling, Psychology
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                     EEG, attention
# 42                                                NaN
# 43                                        memory, MEG
# 44                                 Object recognition
# 45                                                NaN
# 46     Social cognition in neurodegenerative diseases
# 47  Audition, blindness, psychophysics, psychometrics
# 48          3d visualization, image segmentation, MRI
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                           myelin, development, MRI
# 54      Algorithms, efficiency, algebra, cryptography
#
#                                    doctoral_loc  ... phd_qual post_doc_qual  \
# 12                              Rovereto, Italy  ...      Yes           Yes
# 13               Melbourne, Victoria, Australia  ...      Yes            No
# 14                               Birmingham, UK  ...      Yes           Yes
# 15                              Rovereto, Italy  ...      Yes           Yes
# 16                          Pittsburgh, PA, USA  ...      Yes            No
# 17                    Rovereto, Trentino, Italy  ...      Yes           Yes
# 18                        Philadelphia, PA, USA  ...      Yes            No
# 19                               Washington, DC  ...      Yes           Yes
# 20                           Frankfurt, Germany  ...      Yes            No
# 21                                 Paris/France  ...      Yes           Yes
# 22                           San Diego, CA, USA  ...      Yes           Yes
# 23                           Princeton, NJ, USA  ...      Yes            No
# 24                   Seattle, WA, United States  ...      Yes           Yes
# 25                               Miami, FL, USA  ...      Yes            No
# 26                                     York, UK  ...      Yes           Yes
# 27                             Hamburg, Germany  ...      Yes            No
# 28                               Pittsburgh, PA  ...      Yes           Yes
# 29                           Seoul, South Korea  ...      Yes           Yes
# 30                                          NaN  ...       No            No
# 31                       London, United Kingdom  ...      Yes            No
# 32                      Leiden, the Netherlands  ...      Yes            No
# 33                              Boston, MA, USA  ...      Yes            No
# 34               Santa Barbara, California, USA  ...      Yes            No
# 35                  Hanover, New Hampshire, USA  ...      Yes            No
# 36                              Austin, TX, USA  ...      Yes            No
# 37  Rio de Janeiro, Brazil AND Montreal, Canada  ...      Yes           Yes
# 38                           St. Louis, MO, USA  ...      Yes           Yes
# 39                            Jerusalem, Israel  ...      Yes            No
# 40                         Bloomington, IN, USA  ...      Yes            No
# 41                            Berkeley, CA, USA  ...      Yes           Yes
# 42                               Boston, MA USA  ...      Yes           Yes
# 43                           London, London, UK  ...      Yes           Yes
# 44                           Rochester, NY, USA  ...      Yes            No
# 45                           Washington, DC, US  ...      Yes           Yes
# 46                      London, Ontario, Canada  ...      Yes           Yes
# 47                            Berkeley, CA, USA  ...      Yes           Yes
# 48                            Cambridge, MA USA  ...      Yes           Yes
# 49                            Berkeley, CA, USA  ...      Yes           Yes
# 50          Oxford, Oxfordshire, United Kingdom  ...      Yes            No
# 51                                          NaN  ...       No            No
# 52                              Boston, MA, USA  ...      Yes            No
# 53                            Berkeley, CA, USA  ...      Yes           Yes
# 54                 Paris, île-de-France, France  ...      Yes           Yes
#
#    faculty_qual faculty_pos prior_progr_lang                faculty_loc  \
# 12          NaN         NaN              NaN                        NaN
# 13           No         NaN              NaN                        NaN
# 14           No         NaN              NaN                        NaN
# 15           No         NaN              NaN                        NaN
# 16           No         NaN              NaN                        NaN
# 17           No         NaN              NaN                        NaN
# 18           No         NaN              NaN                        NaN
# 19          Yes         NaN              NaN  Dallas, TX, United States
# 20           No         NaN              NaN                        NaN
# 21          Yes         NaN              NaN               Perm, Russia
# 22           No         NaN              NaN                        NaN
# 23           No         NaN              NaN                        NaN
# 24           No         NaN              NaN                        NaN
# 25           No         NaN              NaN                        NaN
# 26           No         NaN              NaN                        NaN
# 27           No         NaN              NaN                        NaN
# 28           No         NaN              NaN                        NaN
# 29           No         NaN              NaN                        NaN
# 30           No         NaN              NaN                        NaN
# 31           No         NaN              NaN                        NaN
# 32           No         NaN              NaN                        NaN
# 33           No         NaN              NaN                        NaN
# 34           No         NaN              NaN                        NaN
# 35           No         NaN              NaN                        NaN
# 36           No         NaN              NaN                        NaN
# 37           No         NaN              NaN                        NaN
# 38          Yes         NaN              NaN            Austin, TX, USA
# 39           No         NaN              NaN                        NaN
# 40           No         NaN              NaN                        NaN
# 41           No         NaN              NaN                        NaN
# 42           No         NaN              NaN                        NaN
# 43           No         NaN              NaN                        NaN
# 44           No         NaN              NaN                        NaN
# 45           No         NaN              NaN                        NaN
# 46           No         NaN              NaN                        NaN
# 47          Yes         NaN              NaN           Seattle, WA, USA
# 48          Yes         NaN              NaN          Worcester, MA USA
# 49          Yes         NaN              NaN            Austin, TX, USA
# 50           No         NaN              NaN                        NaN
# 51           No         NaN              NaN                        NaN
# 52           No         NaN              NaN                        NaN
# 53          Yes         NaN              NaN                 London, UK
# 54           No         NaN              NaN                        NaN
#
#                                   faculty_inst  \
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19               University of Texas at Dallas
# 20                                         NaN
# 21                  Higher School of Economics
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29                                         NaN
# 30                                         NaN
# 31                                         NaN
# 32                                         NaN
# 33                                         NaN
# 34                                         NaN
# 35                                         NaN
# 36                                         NaN
# 37                                         NaN
# 38               University of Texas at Austin
# 39                                         NaN
# 40                                         NaN
# 41                                         NaN
# 42                                         NaN
# 43                                         NaN
# 44                                         NaN
# 45                                         NaN
# 46                                         NaN
# 47                    University of Washington
# 48  University of Massachusetts Medical School
# 49                                   UT Austin
# 50                                         NaN
# 51                                         NaN
# 52                                         NaN
# 53                       Alan Turing Institute
# 54                                         NaN
#
#                                      faculty_research consent  \
# 12                                                NaN     NaN
# 13                                                NaN     Yes
# 14                                                NaN     Yes
# 15                                                NaN     Yes
# 16                                                NaN     Yes
# 17                                                NaN     Yes
# 18                                                NaN     Yes
# 19                   Aging, Decision making, Learning     Yes
# 20                                                NaN     Yes
# 21  diffusion MRI, MRI relaxometry, TMS, EEG, stro...     Yes
# 22                                                NaN     Yes
# 23                                                NaN     Yes
# 24                                                NaN     Yes
# 25                                                NaN     Yes
# 26                                                NaN     Yes
# 27                                                NaN     Yes
# 28                                                NaN     Yes
# 29                                                NaN     Yes
# 30                                                NaN     Yes
# 31                                                NaN     Yes
# 32                                                NaN     Yes
# 33                                                NaN     Yes
# 34                                                NaN     Yes
# 35                                                NaN     Yes
# 36                                                NaN     Yes
# 37                                                NaN     Yes
# 38                                   Neuroinformatics     Yes
# 39                                                NaN     Yes
# 40                                                NaN     Yes
# 41                                                NaN     Yes
# 42                                                NaN     Yes
# 43                                                NaN     Yes
# 44                                                NaN     Yes
# 45                                                NaN     Yes
# 46                                                NaN     Yes
# 47  Data science, neuroinformatics, machine learni...     Yes
# 48  brain development, neurodevelopmental disorder...     Yes
# 49  epilepsy, ECoG, EEG, speech perception, audito...     Yes
# 50                                                NaN     Yes
# 51                                                NaN     Yes
# 52                                                NaN     Yes
# 53        “Data science”, reproducible, “open source”     Yes
# 54                                                NaN     Yes
#
#                                   doc_continent
# 12                              Rovereto, Italy
# 13               Melbourne, Victoria, Australia
# 14                               Birmingham, UK
# 15                              Rovereto, Italy
# 16                          Pittsburgh, PA, USA
# 17                    Rovereto, Trentino, Italy
# 18                        Philadelphia, PA, USA
# 19                               Washington, DC
# 20                           Frankfurt, Germany
# 21                                 Paris/France
# 22                           San Diego, CA, USA
# 23                           Princeton, NJ, USA
# 24                   Seattle, WA, United States
# 25                               Miami, FL, USA
# 26                                     York, UK
# 27                             Hamburg, Germany
# 28                               Pittsburgh, PA
# 29                           Seoul, South Korea
# 30                                          NaN
# 31                       London, United Kingdom
# 32                      Leiden, the Netherlands
# 33                              Boston, MA, USA
# 34               Santa Barbara, California, USA
# 35                  Hanover, New Hampshire, USA
# 36                              Austin, TX, USA
# 37  Rio de Janeiro, Brazil AND Montreal, Canada
# 38                           St. Louis, MO, USA
# 39                            Jerusalem, Israel
# 40                         Bloomington, IN, USA
# 41                            Berkeley, CA, USA
# 42                               Boston, MA USA
# 43                           London, London, UK
# 44                           Rochester, NY, USA
# 45                           Washington, DC, US
# 46                      London, Ontario, Canada
# 47                            Berkeley, CA, USA
# 48                            Cambridge, MA USA
# 49                            Berkeley, CA, USA
# 50          Oxford, Oxfordshire, United Kingdom
# 51                                          NaN
# 52                              Boston, MA, USA
# 53                            Berkeley, CA, USA
# 54                 Paris, île-de-France, France
#
# [43 rows x 37 columns]
